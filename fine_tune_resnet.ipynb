# %%
# !pip install torch
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: torch in /home/hl9h/.local/lib/python3.12/site-packages (2.9.0)
# Requirement already satisfied: filelock in /home/hl9h/.local/lib/python3.12/site-packages (from torch) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /apps/software/standard/core/jupyterlab/4.4.6-py3.12/lib/python3.12/site-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /apps/software/standard/core/jupyterlab/4.4.6-py3.12/lib/python3.12/site-packages (from torch) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in /home/hl9h/.local/lib/python3.12/site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /apps/software/standard/core/jupyterlab/4.4.6-py3.12/lib/python3.12/site-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /apps/software/standard/core/jupyterlab/4.4.6-py3.12/lib/python3.12/site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /home/hl9h/.local/lib/python3.12/site-packages (from torch) (2025.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /home/hl9h/.local/lib/python3.12/site-packages (from torch) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /home/hl9h/.local/lib/python3.12/site-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /home/hl9h/.local/lib/python3.12/site-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /home/hl9h/.local/lib/python3.12/site-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /home/hl9h/.local/lib/python3.12/site-packages (from torch) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /home/hl9h/.local/lib/python3.12/site-packages (from torch) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /home/hl9h/.local/lib/python3.12/site-packages (from torch) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /home/hl9h/.local/lib/python3.12/site-packages (from torch) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /home/hl9h/.local/lib/python3.12/site-packages (from torch) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /home/hl9h/.local/lib/python3.12/site-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /home/hl9h/.local/lib/python3.12/site-packages (from torch) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /home/hl9h/.local/lib/python3.12/site-packages (from torch) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /home/hl9h/.local/lib/python3.12/site-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /home/hl9h/.local/lib/python3.12/site-packages (from torch) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /home/hl9h/.local/lib/python3.12/site-packages (from torch) (1.13.1.3)
# Requirement already satisfied: triton==3.5.0 in /home/hl9h/.local/lib/python3.12/site-packages (from torch) (3.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/hl9h/.local/lib/python3.12/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /apps/software/standard/core/jupyterlab/4.4.6-py3.12/lib/python3.12/site-packages (from jinja2->torch) (3.0.3)

# %%
# !pip install torchvision
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: torchvision in /home/hl9h/.local/lib/python3.12/site-packages (0.24.0)
# Requirement already satisfied: numpy in /apps/software/standard/core/jupyterlab/4.4.6-py3.12/lib/python3.12/site-packages (from torchvision) (2.2.6)
# Requirement already satisfied: torch==2.9.0 in /home/hl9h/.local/lib/python3.12/site-packages (from torchvision) (2.9.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /apps/software/standard/core/jupyterlab/4.4.6-py3.12/lib/python3.12/site-packages (from torchvision) (11.3.0)
# Requirement already satisfied: filelock in /home/hl9h/.local/lib/python3.12/site-packages (from torch==2.9.0->torchvision) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /apps/software/standard/core/jupyterlab/4.4.6-py3.12/lib/python3.12/site-packages (from torch==2.9.0->torchvision) (4.15.0)
# Requirement already satisfied: setuptools in /apps/software/standard/core/jupyterlab/4.4.6-py3.12/lib/python3.12/site-packages (from torch==2.9.0->torchvision) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in /home/hl9h/.local/lib/python3.12/site-packages (from torch==2.9.0->torchvision) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /apps/software/standard/core/jupyterlab/4.4.6-py3.12/lib/python3.12/site-packages (from torch==2.9.0->torchvision) (3.5)
# Requirement already satisfied: jinja2 in /apps/software/standard/core/jupyterlab/4.4.6-py3.12/lib/python3.12/site-packages (from torch==2.9.0->torchvision) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /home/hl9h/.local/lib/python3.12/site-packages (from torch==2.9.0->torchvision) (2025.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /home/hl9h/.local/lib/python3.12/site-packages (from torch==2.9.0->torchvision) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /home/hl9h/.local/lib/python3.12/site-packages (from torch==2.9.0->torchvision) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /home/hl9h/.local/lib/python3.12/site-packages (from torch==2.9.0->torchvision) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /home/hl9h/.local/lib/python3.12/site-packages (from torch==2.9.0->torchvision) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /home/hl9h/.local/lib/python3.12/site-packages (from torch==2.9.0->torchvision) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /home/hl9h/.local/lib/python3.12/site-packages (from torch==2.9.0->torchvision) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /home/hl9h/.local/lib/python3.12/site-packages (from torch==2.9.0->torchvision) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /home/hl9h/.local/lib/python3.12/site-packages (from torch==2.9.0->torchvision) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /home/hl9h/.local/lib/python3.12/site-packages (from torch==2.9.0->torchvision) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /home/hl9h/.local/lib/python3.12/site-packages (from torch==2.9.0->torchvision) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /home/hl9h/.local/lib/python3.12/site-packages (from torch==2.9.0->torchvision) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /home/hl9h/.local/lib/python3.12/site-packages (from torch==2.9.0->torchvision) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /home/hl9h/.local/lib/python3.12/site-packages (from torch==2.9.0->torchvision) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /home/hl9h/.local/lib/python3.12/site-packages (from torch==2.9.0->torchvision) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /home/hl9h/.local/lib/python3.12/site-packages (from torch==2.9.0->torchvision) (1.13.1.3)
# Requirement already satisfied: triton==3.5.0 in /home/hl9h/.local/lib/python3.12/site-packages (from torch==2.9.0->torchvision) (3.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/hl9h/.local/lib/python3.12/site-packages (from sympy>=1.13.3->torch==2.9.0->torchvision) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /apps/software/standard/core/jupyterlab/4.4.6-py3.12/lib/python3.12/site-packages (from jinja2->torch==2.9.0->torchvision) (3.0.3)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
from torchvision import datasets, transforms, models
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import os
import zipfile
import urllib.request
from tqdm import tqdm

# %%
import resnet50

# Set random seeds for reproducibility
np.random.seed(42)
torch.manual_seed(42)
if torch.cuda.is_available():
    torch.cuda.manual_seed(42)

# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Using device: {device}')
# Out:
# Using device: cpu

# %%
# Initialize Configuations and Data Sets

DEVICE = device
NUM_CLASS = 
NUM_EPOCH = 50
LR = 0.0001

train_loader = 
val_loader =

# %%
# Fine Tuning ResNet50 with PlantCLEF Training Data

print("\n" + "="*60)
print("Transfer Learning - Fine Tuning ResNet50 with PlantCLEF Training Data")
print("="*60)

try:
    print("\nFine-tuning ResNet50 ...")
    pretrained_finetune = resnet50.get_resnet50_pretrained(num_classes=NUM_CLASS, fine_tune=True)
    finetune_history = train_model(pretrained_finetune, 
                                   train_loader, 
                                   val_loader,
                                   num_epochs=NUM_EPOCH, 
                                   lr=LR,
                                   device = DEVICE)
    # results['Transfer_Finetune'] = finetune_history['val_acc'][-1]
    plot_training_history(finetune_history, title="Fine Tuning History")
    
except Exception as e:
    print(f"Error in Transfer Learning (Fine-tune): {e}")
    results['Transfer_Finetune'] = 0
